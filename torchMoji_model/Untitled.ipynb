# %%
import pandas as pd
from sklearn.metrics import classification_report

# Load your CSV file
df = pd.read_csv('your_file_mapped.csv')

# Extract true and predicted labels
y_true = df['TrueLabel']
y_pred = df['PredEmotion']

# Generate the classification report
report = classification_report(y_true, y_pred)

# Print the report
print(report)
# Out:
# C:\Users\fahim\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\fahim\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#      Unknown       0.00      0.00      0.00         0
#        anger       0.09      0.07      0.08      1641
#         fear       0.14      0.12      0.13      2709
#          joy       0.59      0.56      0.57      6761
#         love       0.04      0.01      0.02      2373
#      sadness       0.51      0.50      0.50      5797
#     surprise       0.04      0.17      0.07       719
#
#     accuracy                           0.36     20000
#    macro avg       0.20      0.20      0.19     20000
# weighted avg       0.38      0.36      0.37     20000
# C:\Users\fahim\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
